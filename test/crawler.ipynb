# %%
import requests
import json
import os
import time
from bs4 import BeautifulSoup

def get_openai_data(i=0,txt=None):
    url = 'https://gpt-api.putaojie.top/v1/chat/completions'
    headers = {'Authorization': 'Bearer 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','Content-Type': 'application/json'}
    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user", "content": "Notice: If doctor or hospital not in the context, skip this one 假如你是数据工程师，请把如下个人信息按照JSON的格式整理给我：（参考字段：行医，门诊时间，综合评价，资质认证状态，基本信息，简介，姓名，医院/机构，专长，职务，职称，学术兼职，地区，邮箱，手机，昕康ID/XK_ID，履历，教育经历，工作经历，研究，研究方向/临床研究，课题/基金，发表，发表文章，出版著作，专利和软著，执笔共识，成就，荣誉获奖）Return only the translation and nothing else:\n" + txt}]
    }
    try:
        response = requests.post(url, data=json.dumps(data), headers=headers)
    except Exception as e:
        print(e)
    # 处理响应结果

    if response.status_code == 200:
        json_dict = response.json()  # 解析JSON
        # 从JSON字符串中提取内容字段
        content = json.loads(json_dict['choices'][0]['message']['content']) # 获取指定字段
        print(content)
        # with open(f'doc/{i}.json', 'w', encoding='utf-8') as f:
        #     f.write(json.dumps(content, ensure_ascii=False))
    else:
        print("请求失败")

# %%
# 定义要获取的URL列表
"""
http://homepage.hit.edu.cn/majun
"""
url_list = [#"https://www.sysucc.org.cn/node/1478"
    'http://www.ah-zl.com/index.php/content-175',
    # 'http://www.ah-zl.com/index.php/content-93',
    # 'https://www.ahslyy.com.cn/mz/Department/info_2694.aspx?itemid=74796',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/ywlc/content.jsp?id=1119',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/chn_1043/content.jsp?id=412',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/ywlc/content.jsp?id=1120',
    # 'http://www.byyfy.net/cn//info_49.aspx?itemid=9915',
    # 'https://www.puh3.net.cn/xynk/info/1461/1511.htm',
    # 'https://www.puh3.net.cn/hxywzzyxk/info/1351/3111.htm',
    # 'https://www.puh3.net.cn/zlflk/info/1004/1131.htm',
    # 'https://www.pkufh.com/Html/Doctors/Main/Index_778.html',
    # 'https://www.pkufh.com/Html/Doctors/Main/Index_1366.html',
    # 'https://www.pkuph.cn/Article/Index/teamList/id/1977.html',
    # 'https://www.pkuph.cn/Article/Index/teamList/id/1601.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1133.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1337.html',
    # 'http://www.bjbryy.cn/Html/News/Articles/358.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1049.html',
    # 'https://www.zs-hospital.sh.cn/fddxfszsyy/zjxz_gzlwk/zjxz_gzlwk.html',
    # 'https://www.gdghospital.org.cn/Expertlistt/info_itemid_23176_subjectid_24.html',
    # 'http://www.hrbsdyyy.org.cn/mymj_details/5407959.html',
    # 'http://www.anti-cancer.com.cn/Html/Doctors/Main/SearchIndex_472.html',
    # 'https://www.whuh.com/info/1272/7247.htm',
    # 'https://www.jdyy.cn/index.php?m=home&c=View&a=index&aid=2802',
    # 'https://www.zchospital.com/cn/expert/1',
    # 'http://www.jxszlyy.com/info/1372/91108.htm',
    # 'https://www.lzdxdyyy.com/Web/Ldyy/UserDetail/4703',
    # 'http://www.nh2h.com/a/zhuangjiajs/yijixilei/yjk/2019/0706/196.html',
    # 'https://www.shsfkyy.com/list/76/1183.html',
    # 'https://www.shxkyy.com/hz/list/197/2779.html',
    # 'http://www.wchscu.cn/expertlist/detail/68892.html',
    # 'https://zhaosheng.ccucm.edu.cn/info/1025/15524.htm',
    # 'https://www.z2hospital.com/contents/286/19004.html',
    # 'https://www.zy91.com/department/doctor/74/477',
    # 'http://www.zjhospital.com.cn/index.php/Person/eContent/id/59/cCode/104104',
    # 'https://www.chinablood.com.cn/jyb/department_navigation/bxbzlzx/doctor/630.html',
    # 'http://www.cicams.ac.cn/dzb/navigation/neike/zhuan/3495.html',
    # 'https://www.sysucc.org.cn/node/1473'
]

# 创建data文件夹
# if not os.path.exists('doc'):
#     os.mkdir('doc')
i=0
for url in url_list:
    try:
        print(url)
        response = requests.get(url,verify=False)
        soup = BeautifulSoup(response.content, 'html.parser')
        # 从HTML中提取出文本内容并去除换行、空格等字符
        text = soup.get_text().replace('\n', '').replace('\r', '').replace('\t', '').strip()
        print(text)
        get_openai_data(i, text)
    except:
        continue
    i += 1
    # 暂停20秒钟
    time.sleep(21)
# Out:
# http://www.ah-zl.com/index.php/content-175
# 满祎-知名专家-安徽济民肿瘤医院      欢迎访问     安徽济民肿瘤医院官方网站首页济民简介济民简介医院荣誉人才招聘 新闻中心医院动态媒体报道学术交流医院通知、公告 就医指南来院路线医院地图入院流程出院流程门诊须知多学科专家会诊（MDT） 科室介绍知名专家尖端设备协会组织药物试验GCP平台GCP项目流程伦理委员会 党建园地联系我们在线预约知名专家当前位置：首页>>知名专家知名专家满祎日期：2020-02-23点击：5799次字体：[大] [小]打印关闭在线预约安徽济民肿瘤医院副院长、肿瘤外科主任。安徽医科大学临床医学专业毕业，研究生学历，副主任医师。兼任中国抗癌协会青年理事会理事；安徽省抗癌协会常务理事兼副秘书长；安徽省抗癌协会乳腺癌专业委员会副主任委员、头颈肿瘤外科委员会常委、甲状腺癌专业委员会常委；先后在国家核心期刊发表学术论文数篇，出版论著《临床实用肿瘤学》。« 返回上一页上一条：石金东 下一条：王本忠友情链接：安徽省医院协会民营医院管理分会安徽省健康服务业协会复星健康      Copyright © 2004-2018 安徽济民肿瘤医院      All Rights Reserved，未经授权，禁止抄袭转载 地址：安徽省合肥市瑶海工业园新海大道888号，服务热线：400-021-6698， ICP备案证号：皖ICP备11005922号-4 公安备案号：34019002600181分享网站：
# ...

# %%
import requests
import json
import os
import time
from bs4 import BeautifulSoup

def get_openai_data(i=0,txt=None):
    url = 'https://gpt-api.putaojie.top/v1/chat/completions'
    headers = {'Authorization': 'Bearer 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','Content-Type': 'application/json'}
    data = {
        "model": "gpt-3.5-turbo-16k",
        "messages": [{"role": "user", "content": "Notice: If doctor or hospital not in the context, skip this one 假如你是数据工程师，请把如下个人信息按照JSON的格式整理给我：（参考字段：行医，门诊时间，综合评价，资质认证状态，基本信息，简介，姓名，医院/机构，专长，职务，职称，学术兼职，地区，邮箱，手机，昕康ID/XK_ID，履历，教育经历，工作经历，研究，研究方向/临床研究，课题/基金，发表，发表文章，出版著作，专利和软著，执笔共识，成就，荣誉获奖）Return only the translation and nothing else:\n" + txt}]
    }
    try:
        response = requests.post(url, data=json.dumps(data), headers=headers)
    except Exception as e:
        print(e)
    # 处理响应结果

    if response.status_code == 200:
        json_dict = response.json()  # 解析JSON
        # 从JSON字符串中提取内容字段
        content = json.loads(json_dict['choices'][0]['message']['content']) # 获取指定字段
        print(content)
        # with open(f'doc/{i}.json', 'w', encoding='utf-8') as f:
        #     f.write(json.dumps(content, ensure_ascii=False))
    else:
        print("请求失败")

# %%
# 定义要获取的URL列表
"""
http://homepage.hit.edu.cn/majun
"""
url_list = [#"https://www.sysucc.org.cn/node/1478"
    'http://www.ah-zl.com/index.php/content-175',
    # 'http://www.ah-zl.com/index.php/content-93',
    # 'https://www.ahslyy.com.cn/mz/Department/info_2694.aspx?itemid=74796',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/ywlc/content.jsp?id=1119',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/chn_1043/content.jsp?id=412',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/ywlc/content.jsp?id=1120',
    # 'http://www.byyfy.net/cn//info_49.aspx?itemid=9915',
    # 'https://www.puh3.net.cn/xynk/info/1461/1511.htm',
    # 'https://www.puh3.net.cn/hxywzzyxk/info/1351/3111.htm',
    # 'https://www.puh3.net.cn/zlflk/info/1004/1131.htm',
    # 'https://www.pkufh.com/Html/Doctors/Main/Index_778.html',
    # 'https://www.pkufh.com/Html/Doctors/Main/Index_1366.html',
    # 'https://www.pkuph.cn/Article/Index/teamList/id/1977.html',
    # 'https://www.pkuph.cn/Article/Index/teamList/id/1601.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1133.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1337.html',
    # 'http://www.bjbryy.cn/Html/News/Articles/358.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1049.html',
    # 'https://www.zs-hospital.sh.cn/fddxfszsyy/zjxz_gzlwk/zjxz_gzlwk.html',
    # 'https://www.gdghospital.org.cn/Expertlistt/info_itemid_23176_subjectid_24.html',
    # 'http://www.hrbsdyyy.org.cn/mymj_details/5407959.html',
    # 'http://www.anti-cancer.com.cn/Html/Doctors/Main/SearchIndex_472.html',
    # 'https://www.whuh.com/info/1272/7247.htm',
    # 'https://www.jdyy.cn/index.php?m=home&c=View&a=index&aid=2802',
    # 'https://www.zchospital.com/cn/expert/1',
    # 'http://www.jxszlyy.com/info/1372/91108.htm',
    # 'https://www.lzdxdyyy.com/Web/Ldyy/UserDetail/4703',
    # 'http://www.nh2h.com/a/zhuangjiajs/yijixilei/yjk/2019/0706/196.html',
    # 'https://www.shsfkyy.com/list/76/1183.html',
    # 'https://www.shxkyy.com/hz/list/197/2779.html',
    # 'http://www.wchscu.cn/expertlist/detail/68892.html',
    # 'https://zhaosheng.ccucm.edu.cn/info/1025/15524.htm',
    # 'https://www.z2hospital.com/contents/286/19004.html',
    # 'https://www.zy91.com/department/doctor/74/477',
    # 'http://www.zjhospital.com.cn/index.php/Person/eContent/id/59/cCode/104104',
    # 'https://www.chinablood.com.cn/jyb/department_navigation/bxbzlzx/doctor/630.html',
    # 'http://www.cicams.ac.cn/dzb/navigation/neike/zhuan/3495.html',
    # 'https://www.sysucc.org.cn/node/1473'
]

# 创建data文件夹
# if not os.path.exists('doc'):
#     os.mkdir('doc')
i=0
for url in url_list:
    try:
        print(url)
        response = requests.get(url,verify=False)
        soup = BeautifulSoup(response.content, 'html.parser')
        # 从HTML中提取出文本内容并去除换行、空格等字符
        text = soup.get_text().replace('\n', '').replace('\r', '').replace('\t', '').strip()
        print(text)
        get_openai_data(i, text)
    except:
        continue
    i += 1
    # 暂停20秒钟
    time.sleep(21)
# Out:
# http://www.ah-zl.com/index.php/content-175
# 满祎-知名专家-安徽济民肿瘤医院      欢迎访问     安徽济民肿瘤医院官方网站首页济民简介济民简介医院荣誉人才招聘 新闻中心医院动态媒体报道学术交流医院通知、公告 就医指南来院路线医院地图入院流程出院流程门诊须知多学科专家会诊（MDT） 科室介绍知名专家尖端设备协会组织药物试验GCP平台GCP项目流程伦理委员会 党建园地联系我们在线预约知名专家当前位置：首页>>知名专家知名专家满祎日期：2020-02-23点击：5799次字体：[大] [小]打印关闭在线预约安徽济民肿瘤医院副院长、肿瘤外科主任。安徽医科大学临床医学专业毕业，研究生学历，副主任医师。兼任中国抗癌协会青年理事会理事；安徽省抗癌协会常务理事兼副秘书长；安徽省抗癌协会乳腺癌专业委员会副主任委员、头颈肿瘤外科委员会常委、甲状腺癌专业委员会常委；先后在国家核心期刊发表学术论文数篇，出版论著《临床实用肿瘤学》。« 返回上一页上一条：石金东 下一条：王本忠友情链接：安徽省医院协会民营医院管理分会安徽省健康服务业协会复星健康      Copyright © 2004-2018 安徽济民肿瘤医院      All Rights Reserved，未经授权，禁止抄袭转载 地址：安徽省合肥市瑶海工业园新海大道888号，服务热线：400-021-6698， ICP备案证号：皖ICP备11005922号-4 公安备案号：34019002600181分享网站：
# {'姓名': '满祎', '医院/机构': '安徽济民肿瘤医院', '职务': '副院长、肿瘤外科主任', '学术兼职': '中国抗癌协会青年理事会理事；安徽省抗癌协会常务理事兼副秘书长；安徽省抗癌协会乳腺癌专业委员会副主任委员、头颈肿瘤外科委员会常委、甲状腺癌专业委员会常委', '发表': '在国家核心期刊发表学术论文数篇', '出版著作': '《临床实用肿瘤学》', '荣誉获奖': ''}

# %%
# 定义要获取的URL列表
"""
http://homepage.hit.edu.cn/majun
"""
url_list = [#"https://www.sysucc.org.cn/node/1478"
    'http://www.ah-zl.com/index.php/content-175',
    # 'http://www.ah-zl.com/index.php/content-93',
    # 'https://www.ahslyy.com.cn/mz/Department/info_2694.aspx?itemid=74796',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/ywlc/content.jsp?id=1119',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/chn_1043/content.jsp?id=412',
    # 'http://www.ay2fy.com/yygk/yygk-zmzj/ywlc/content.jsp?id=1120',
    # 'http://www.byyfy.net/cn//info_49.aspx?itemid=9915',
    # 'https://www.puh3.net.cn/xynk/info/1461/1511.htm',
    # 'https://www.puh3.net.cn/hxywzzyxk/info/1351/3111.htm',
    # 'https://www.puh3.net.cn/zlflk/info/1004/1131.htm',
    # 'https://www.pkufh.com/Html/Doctors/Main/Index_778.html',
    # 'https://www.pkufh.com/Html/Doctors/Main/Index_1366.html',
    # 'https://www.pkuph.cn/Article/Index/teamList/id/1977.html',
    # 'https://www.pkuph.cn/Article/Index/teamList/id/1601.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1133.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1337.html',
    # 'http://www.bjbryy.cn/Html/News/Articles/358.html',
    # 'https://www.bjcancer.org/Html/Doctors/Main/Detail_1049.html',
    # 'https://www.zs-hospital.sh.cn/fddxfszsyy/zjxz_gzlwk/zjxz_gzlwk.html',
    # 'https://www.gdghospital.org.cn/Expertlistt/info_itemid_23176_subjectid_24.html',
    # 'http://www.hrbsdyyy.org.cn/mymj_details/5407959.html',
    # 'http://www.anti-cancer.com.cn/Html/Doctors/Main/SearchIndex_472.html',
    # 'https://www.whuh.com/info/1272/7247.htm',
    # 'https://www.jdyy.cn/index.php?m=home&c=View&a=index&aid=2802',
    # 'https://www.zchospital.com/cn/expert/1',
    # 'http://www.jxszlyy.com/info/1372/91108.htm',
    # 'https://www.lzdxdyyy.com/Web/Ldyy/UserDetail/4703',
    # 'http://www.nh2h.com/a/zhuangjiajs/yijixilei/yjk/2019/0706/196.html',
    # 'https://www.shsfkyy.com/list/76/1183.html',
    # 'https://www.shxkyy.com/hz/list/197/2779.html',
    # 'http://www.wchscu.cn/expertlist/detail/68892.html',
    # 'https://zhaosheng.ccucm.edu.cn/info/1025/15524.htm',
    # 'https://www.z2hospital.com/contents/286/19004.html',
    # 'https://www.zy91.com/department/doctor/74/477',
    # 'http://www.zjhospital.com.cn/index.php/Person/eContent/id/59/cCode/104104',
    # 'https://www.chinablood.com.cn/jyb/department_navigation/bxbzlzx/doctor/630.html',
    # 'http://www.cicams.ac.cn/dzb/navigation/neike/zhuan/3495.html',
    # 'https://www.sysucc.org.cn/node/1473'
]

# 创建data文件夹
# if not os.path.exists('doc'):
#     os.mkdir('doc')
i=0
for url in url_list:
    try:
        print(url)
        response = requests.get(url,verify=False)
        soup = BeautifulSoup(response.content, 'html.parser')
        # 从HTML中提取出文本内容并去除换行、空格等字符
        text = soup.get_text().replace('\n', '').replace('\r', '').replace('\t', '').strip()
        print(text)
        get_openai_data(i, text)
    except:
        continue
    i += 1
    # 暂停20秒钟
    time.sleep(21)
# Out:
# http://www.ah-zl.com/index.php/content-175
# 满祎-知名专家-安徽济民肿瘤医院      欢迎访问     安徽济民肿瘤医院官方网站首页济民简介济民简介医院荣誉人才招聘 新闻中心医院动态媒体报道学术交流医院通知、公告 就医指南来院路线医院地图入院流程出院流程门诊须知多学科专家会诊（MDT） 科室介绍知名专家尖端设备协会组织药物试验GCP平台GCP项目流程伦理委员会 党建园地联系我们在线预约知名专家当前位置：首页>>知名专家知名专家满祎日期：2020-02-23点击：5799次字体：[大] [小]打印关闭在线预约安徽济民肿瘤医院副院长、肿瘤外科主任。安徽医科大学临床医学专业毕业，研究生学历，副主任医师。兼任中国抗癌协会青年理事会理事；安徽省抗癌协会常务理事兼副秘书长；安徽省抗癌协会乳腺癌专业委员会副主任委员、头颈肿瘤外科委员会常委、甲状腺癌专业委员会常委；先后在国家核心期刊发表学术论文数篇，出版论著《临床实用肿瘤学》。« 返回上一页上一条：石金东 下一条：王本忠友情链接：安徽省医院协会民营医院管理分会安徽省健康服务业协会复星健康      Copyright © 2004-2018 安徽济民肿瘤医院      All Rights Reserved，未经授权，禁止抄袭转载 地址：安徽省合肥市瑶海工业园新海大道888号，服务热线：400-021-6698， ICP备案证号：皖ICP备11005922号-4 公安备案号：34019002600181分享网站：
# ...
